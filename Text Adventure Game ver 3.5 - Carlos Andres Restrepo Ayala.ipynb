# %%
# Text Adventure Game - Carlos Andres Restrepo Ayala
# Meet the Vikings
# Assumption: User has a minimal concept about History Channel's Serie Vikings

"""
    Docstring:
    
    A) Meet the Vikings is a game in which the user has to answer questions as a
    randomly choosen character of TV Serie Vikings would do. Each character has
    specific features and every question is related with one of that features.
    If the answer is correct the user continues to next port, but it the answer
    is wrong, the user loses the game.
    
    B) Bugs or malfunction as the code expected.
    - Although "play again" is not a requirement, I can't make that "play again" works. 
    Always find errors on Travel function, using different alternatives to include that 
    posibility. No code related with "play again" is included in the sent version.
"""

# Predefinition of required variables for running the code

# Importing area for the chosen character and the exits when user loses the game
import random
from sys import exit

# Define Ending ports that are used in the Win and Fail functions
ports                     = ['Kategat', 'Wessex', 'Iceland', 'Normandy']

# List of alternatives based on types of features for build the characters
type_of_thinking          = ['Analytical' , 'Emotional']

type_of_planning          = ['Always a plan' , 'Wait for opportunity', 'Always a belief',
                             'Take things as they come']

type_of_desire            = ['Knowlegde', 'Peace', 'Glory', 'Loyalty']

type_of_personality       = ['Conqueror', 'Supportive', 'Figther', 'Explorer']

# List of Game Characters of History Channel's Serie Vikings
Characters                = ['Ragnar', 'Lagertha', 'Floki', 'Rollo', 'Bjorn Ironside', 'Ivar - The Bonless' ]

secret_character_features = []

#  A number is used instead of questions to simplify the code because is used for chose questions randomly and the    
#order in which that questions are made. 
questions                 = [1,2,3,4]


# Use this list to keep in the computer memory the features implies the User's answers but every answer is
# totally independet of the rest answers and independent of questions of diferente stages
user_features             = ['none1','none2', 'none3', 'none4']


#############################################################################
# Define personal features of each characters of History Channel's Serie Vikings
# Build Ragnars Character, feature by feature
# Each character has a different set of characteristics

Ragnar_features = []
Ragnar_features.append (type_of_thinking [0])
Ragnar_features.append (type_of_planning [0])
Ragnar_features.append (type_of_desire [0])
Ragnar_features.append (type_of_personality [0])

# Build Lagertha Character, feature by feature
Lagertha_features = []
Lagertha_features.append (type_of_thinking [1])
Lagertha_features.append (type_of_planning [1])
Lagertha_features.append (type_of_desire [1])
Lagertha_features.append (type_of_personality [1])

# Build Floki Character, feature by feature
Floki_features = []
Floki_features.append (type_of_thinking [1])
Floki_features.append (type_of_planning [2])
Floki_features.append (type_of_desire [1])
Floki_features.append (type_of_personality [1])

# Build Rollo Character, feature by feature
Rollo_features = []
Rollo_features.append (type_of_thinking [1])
Rollo_features.append (type_of_planning [3])
Rollo_features.append (type_of_desire [2])
Rollo_features.append (type_of_personality [2])

# Build Bjorn Ironside Character, feature by feature
Bjorn_Ironside_features = []
Bjorn_Ironside_features.append (type_of_thinking [0])
Bjorn_Ironside_features.append (type_of_planning [3])
Bjorn_Ironside_features.append (type_of_desire [3])
Bjorn_Ironside_features.append (type_of_personality [3])

# Build Ivar "The Bonless" Character, feature by feature
Ivar_The_Bonless_features = []
Ivar_The_Bonless_features.append (type_of_thinking [0])
Ivar_The_Bonless_features.append (type_of_planning [0])
Ivar_The_Bonless_features.append (type_of_desire [2])
Ivar_The_Bonless_features.append (type_of_personality [0])

#############################################################################

# Random select of secret_character and transfer the character features to
# List secret_character_features that is used in Travel function

secret_character = random.choice(Characters)
if secret_character == 'Ragnar':
     secret_character_features = Ragnar_features
elif secret_character == 'Lagertha':
     secret_character_features = Lagertha_features
elif secret_character == 'Floki':
     secret_character_features = Floki_features
elif secret_character == 'Rollo':
     secret_character_features = Rollo_features
elif secret_character == 'Bjorn Ironside':
     secret_character_features = Bjorn_Ironside_features
elif secret_character == 'Ivar - The Bonless':
     secret_character_features = Ivar_The_Bonless_features
else:
    print (""" Something was wrong""")


# Until this point all variables and list are requeired to prepare the game


############################################################################
# Text Adventure Game Starts

# First stage - Joining the crew

def start():
    # Greeting and presentation

    print (f"""
    {'--' * 40}
    Meet the Vikings
    {'--' * 40}
    As a true Viking, I suppose you are excited to be sailing again. 
    We only have one day left to start our new adventure and a great brave Viking is always welcome to join us.""")

    message = input (prompt = """We only have names for recognized leaders. The rest of us are just Vikings.
    So... tell me Viking, Do you have a message for one of our SIX leaders?""")

    # This "IF" doesn't have an impact on the game. Ii is used to give context for the user.
    if message == 'Y' or message == 'y' or message == 'Yes' or message == 'YES':

        print (f""" \n\n Yeap. It is true, But don't say the name out loud.
        Just remmeber that is the well-known   --""", end =" ")
        print (f'\033[1m', end = " ") 
        print (f"""{secret_character}. --""") 
        print (f'\033[0m', end =" ")
        print(f"""BUT... our captain likes riddles. Therefore, he will ask you some questions that you must answer as if you were--""", end =" ")
        print (f'\033[1m', end = " ") 
        print (f"""{secret_character}. --""") 
        print (f'\033[0m', end =" ")
        print ("""Depending on whether your answer is correct or incorrect, it will guide us to one port or another.""")
    
    elif message != 'Y' or message != 'y' or message != 'Yes' or message != 'YES':
        print (f"""\n\n I understand that you are cautious and say a codename or even don't say anything at all... 
        in any case we were waiting for you. \n\n 
        The coat of arms that you have is that of to the well-known   --""", end =" ")
        print (f'\033[1m', end = " ") 
        print (f"""{secret_character}. --""") 
        print (f'\033[0m', end =" ")
        print(f"""BUT... our captain likes riddles. Therefore, he will ask you some questions that you must answer as if you were--""", end =" ")
        print (f'\033[1m', end = " ") 
        print (f"""{secret_character}. --""") 
        print (f'\033[0m', end =" ")
        print ("""Depending on whether your answer is correct or incorrect, it will guide us to one port or another.""")
    
    else:
        print (""" You don't see like a real Viking... get out of here!!!""")
    
    
    # The user has three chances to leave with the crew, just have to say Y, y, yes, Yes or YES
    chances_to_leave = 3
    while chances_to_leave >0:
        go_to_travel = input (prompt = "\n Are you ready to leave tomorrow?")
        if 'Y' in go_to_travel or 'y' in go_to_travel or 'Yes' in go_to_travel or 'yes' in go_to_travel or 'YES' in go_to_travel:
            travel ()
            break
        else:
            chances_to_leave -= 1
            print (f""" You have {chances_to_leave} opportunities to leave and the message wouldn't be delivered""")
            
            if chances_to_leave == 0:
                fail ()




    
# Second stage. This is the core of the code. 
# Of the four available questions, the code choose three and makes the questions randomly.

def travel():
    
    # Count for the three questions chosen and remove each question of the list when was selected.
    # Use of "choise" isn't a spelling error. It is the variable that works in the previos versions of the code.
    # That is used to avoid any mistake typing random.choice or any statement if the code.
    num_questions = 3
    while num_questions >0:
        question = random.choice(questions)
        num_questions -= 1

        # Question 1 and results of question 1
        if question == 1:
            # Question 1 - Type of Thinking

            # Replace the none(1,2,3,4) in user_features and that is used to check if the answer is correct or wrong
            # Elimitante the number of the question of the list of posibilities. All the randomly questions
            # are made in the same stage.
            input("press <Enter> to continue")
            questions.remove (1)
            user_features.remove ('none1')
            choise_one = input( prompt = """ 
                        \n\n
                        About how hard could be study at Hult, you:

                        a. Use your background to prepare yourself
                        b. You let yourself be permeate with of Silicon Valley's Feeling

                        To chose the first option type \"a" or \"yourself"
                        To chose the second option type \"b" or \"feeling" """)


            # An If to manage possible user's answers

            if "a" in choise_one or "A" in choise_one or "sel" in choise_one or "SEL" in choise_one:
                choise_one = type_of_thinking [0]

            elif "b" in choise_one or "B" in choise_one or "eel" in choise_one or "EEL" in choise_one:
                choise_one = type_of_thinking [1]

            else: # To give the user a second chance to answer
                print (""" 



                I'm sorry I didn't understand your answer. Please repeat your answer """)
                choise_one = input( prompt = """ About how hard could be study at Hult, you:

                    a. Use your background to prepare yourself
                    b. You let yourself be permeate with of Silicon Valley's Feeling

                    To chose the first option type \"a" or \"yourself"
                    To chose the second option type \"b" or \"feeling" """)


            # An If to take the crew to the next port if the answer is correct or left the viking behind if 
            # the answer is incorrect

            if choise_one  == secret_character_features[0]:
                print (""" \n\n
                After a day of sailing, we have reached a port thats looks like Paris
                """)

            else:
                print ("""\n\n You don't look like a real Viking... get out of here!!!
                You were taked by an army that look like French army and could be in jail or somewhere else... 
                maybe someone remember you but We won't look for descendants or anyone who miss you""")
                fail()
                break

        # Question 2 and results of question 2
        if question == 2:
            # Question 2 - Type of planing

            # Replace the none(1,2,3,4) in user_features and that is used to check if the answer is correct or wrong
            # Elimitante the number of the question of the list of posibilities. All the randomly questions
            # are made in the same stage.

            input("press <Enter> to continue")
            questions.remove (2)
            user_features.remove ('none2')
            choise_two = input( prompt = """ \n\n 
                        Given the Covid Quarantine, for you arrival to San Francisco, 
                        you:

                        a. Wait in your home country for the opportunity to make the trip
                        b. Look for different alternatives to make the trip
                        c. Adapt your expectative to migration policies updates
                        d. Have faith that everything will work out

                        To chose the first option type \"a" or \"wait"
                        To chose the second option type \"b" or \"look for"
                        To chose the third option type \"c" or \"adapt"
                        To chose the forth option type \"d" or \"faith"
                        """)

            # An If to manage possible user's answers
            if "a" in choise_two or "A" in choise_two or "ait" in choise_two or "AIT" in choise_two:
                choise_two = type_of_planning [1]

            elif "b" in choise_two or "B" in choise_two or "ook" in choise_two or "OOK" in choise_two:
                choise_two = type_of_planning [0]

            elif "c" in choise_two or "C" in choise_two or "dap" in choise_two or "DAP" in choise_two:
                choise_two = type_of_planning [3]

            elif "d" in choise_two or "D" in choise_two or "fai" in choise_two or "FAI" in choise_two:
                choise_two = type_of_planning [2] 

            else: # To give the user a second chance to answer
                print (""" \n\n\n

                I'm sorry I didn't understand your answer. Please repeat your answer """)
                choise_two = input( prompt = """ \n\n
                    Given the Covid Quarantine, for you arrival to San Francisco, you:

                    a. Wait in your home country for the opportunity to make the trip
                    b. Look for different alternatives to make the trip
                    c. Adapt your expectative to migration policies updates
                    d. Have faith that everything will work out

                    To chose the first option type \"a" or \"wait"
                    To chose the second option type \"b" or \"look for"
                    To chose the third option type \"c" or \"adapt"
                    To chose the forth option type \"d" or \"faith"
                    """)


            # An If to take the crew to the next port if the answer is correct or left the viking behind if 
            # the answer is incorrect
            if choise_two == secret_character_features[1]:
                print (""" \n\n
                After a day of sailing, we have reached a port thats looks like Gibraltar 
                """)

            else:
                print ("""\n\n You don't look like a real Viking... get out of here!!!
                You were taked by an army that look like Spanish army and could be in jail or somewhere else... 
                maybe someone remember you but We won't look for descendants or anyone who miss you""")
                fail()
                break

        # Question 3 and results of question 3
        if question == 3:
            # Question 3 - Type of desire

            # Replace the none(1,2,3,4) in user_features and that is used to check if the answer is correct or wrong
            # Elimitante the number of the question of the list of posibilities. All the randomly questions
            # are made in the same stage.

            input("press <Enter> to continue")
            questions.remove (3)
            user_features.remove ('none3')

            choise_three = input( prompt = """ \n\
            After a month sleeping 4 hours per day, doing the "Text Adventure Game", you:

            a. Take a weekend off with a book
            b. Try to understand what you could do better
            c. Compare you code with the best ranked codes
            d. Go to a bar dor drink beers with your classmates 

            To chose the first option type \"a" or \"weekend off"
            To chose the second option type \"b" or \"understand"
            To chose the third option type \"c" or \"compare"
            To chose the forth option type \"d" or \"drink"
            """)


            # An If to manage possible user's answers
            if "a" in choise_three or "A" in choise_three or "end" in choise_three or "END" in choise_three:
                choise_three = type_of_desire [1] 

            elif "b" in choise_three or "B" in choise_three or "sta" in choise_three or "STA" in choise_three:
                    choise_three = type_of_desire [0] 

            elif "c" in choise_three or "C" in choise_three or "par" in choise_three or "PAR" in choise_three:
                    choise_three = type_of_desire [2] 

            elif "d" in choise_three or "D" in choise_three or "ink" in choise_three or "INK" in choise_three:
                    choise_three = type_of_desire [3] 

            else: # To give the user a second chance to answer
                print (""" 



                I'm sorry I didn't understand your answer. Please repeat your answer """)
                choise_three = input( prompt = """ \n\n
                fter a month sleeping 4 hours per day, doing the "Text Adventure Game", you:

                    a. Take a weekend off with a book
                    b. Try to understand what you could do better
                    c. Compare you code with the best ranked codes
                    d. Go to a bar dor drink beers with your classmates 

                    To chose the first option type \"a" or \"weekend off"
                    To chose the second option type \"b" or \"understand"
                    To chose the third option type \"c" or \"compare"
                    To chose the forth option type \"d" or \"drink"
                    """)

            # An If to take the crew to the next port if the answer is correct or left the viking behind if 
            # the answer is incorrect
            if choise_three == secret_character_features[2]:
                print (""" \n\n
                After a day of sailing, we have reached a port thats looks like Sicilia 
                """)

            else:
                print ("""\n\n You don't look like a real Viking... get out of here!!!
                You were taked by an army that look like Roman army and could be in jail or somewhere else... 
                maybe someone remember you but We won't look for descendants or anyone who miss you""")
                fail()
                break


        # Question 4 and results of question 4
        if question == 4:
            # Question 4 - Type of personality

            # Replace the none(1,2,3,4) in user_features and that is used to check if the answer is correct or wrong
            # Elimitante the number of the question of the list of posibilities. All the randomly questions
            # are made in the same stage.

            input("press <Enter> to continue")
            questions.remove (4)
            user_features.remove ('none4')

            choise_four = input( prompt = """ In a hiking weekend with friends, and most of them 
            are falling behind, you:

            a. You take the opportunity to hik beyond and see new areas that other won't do
            b. Hurries the most backward to walk faster
            c. You strongly motivate others to hik fast to reach a better performance as a team
            d. Help the most backward to carry their backpack

            To chose the first option type \"a" or \"beyond"
            To chose the second option type \"b" or \"hurries"
            To chose the third option type \"c" or \"motivate"
            To chose the forth option type \"d" or \"help"
            """)


            # An If to manage possible user's answers
            if "a" in choise_four or "A" in choise_four or "ond" in choise_four or "OND" in choise_four:
                choise_four = type_of_personality [3] 

            elif "b" in choise_four or "B" in choise_four or "rri" in choise_four or "RRI" in choise_four:
                    choise_four = type_of_personality [2] 

            elif "c" in choise_four or "C" in choise_four or "iva" in choise_four or "IVA" in choise_four:
                    choise_four = type_of_personality [0] 

            elif "d" in choise_four or "D" in choise_four or "elp" in choise_four or "ELP" in choise_four:
                    choise_four = type_of_personality [1] 

            else: # To give the user a second chance to answer
                print (""" 



                I'm sorry I didn't understand your answer. Please repeat your answer """)
                choise_four = input( prompt = """ About how hard could be study at Hult, you:

                    a. You take the opportunity to hik beyond and see new areas that other won't do
                    b. Hurries the most backward to walk faster
                    c. You strongly motivate others to hik fast to reach a better performance as a team
                    d. Help the most backward to carry their backpack

                    To chose the first option type \"a" or \"beyond"
                    To chose the second option type \"b" or \"hurries"
                    To chose the third option type \"c" or \"motivate"
                    To chose the forth option type \"d" or \"help" 
                    """)

            # An If to take the crew to the next port if the answer is correct or left the viking behind if 
            # the answer is incorrect
            if choise_four == secret_character_features[3]:
                print (""" \n\n
                After a day of sailing, we have reached a port thats looks like Athenas 
                """)

            else:
                print ("""\n\n You don't look like a real Viking... get out of here!!!
                You were taked by an army that look like Greek army and could be in jail or somewhere else... 
                maybe someone remember you but We won't look for descendants or anyone who miss you""")
                fail()
                break

    deliver ()



# Third stage - The user answer a question about what want to drink. The questions strongly suggest the
# wine but that is only correcto for Rollo who lives in France in the recent seasons.

def deliver ():
    drink = input (prompt = """\n\n Do you want  wine or beer to drinkr?
    A true Viking never turns down a drink""")
    if secret_character =="Rollo" and drink =="wine" and drink =="Wine" and drink =="WINE":
        win ()
    elif secret_character =="Rollo" and drink !="wine" and drink !="Wine" and drink !="WINE":
        print ("Maybe you just have to remember that He lives in France")
        deliver ()
    else:
        win ()


## Fail function
# While at the beginning it looks like a function that is better coded usin a for loop, but
# each fail print is different for each character. In that case the for loop will require many "ifs".
# The code uses the place when the selected character died (or supouse to) in the TV serie.

def fail ():
    if secret_character == 'Ragnar':
        print (f"""
        After many days ... You reached {ports [1]} but Ragnar is now in {ports [0]}. 
        You try to walk to {ports [0]} but it is very cold and you died
        smiling in a place very close to {ports [1]} going to heaven or Valhala""")
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
        
    elif secret_character == 'Lagertha':
        print (f"""
        After many days ... You reached {ports [2]} but Lagertha is now in {ports [0]}. 
        You try to walk to {ports [0]} but you died by a drunk\'s knife close to {ports [2]} """)
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
        
    elif secret_character == 'Floki':
        print (f"""
        After many days ... You reached {ports [3]} but Floki is now in {ports [2]}.
        You try to walk to {ports [2]} and you could have died on cave... no one really knows""")
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
        
    elif secret_character == 'Rollo':
        print (f"""
        After many days ... You reached {ports [1]} but Rollo is now in {ports [3]}.
        You try to walk to {ports [3]} and you died thinking you were in France""")
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
        
    elif secret_character == 'Bjorn Ironside':
        print (f"""
        After many days ... You reached {ports [3]} but Bjorn is now in {ports [0]}.
        You try to walk to {ports [0]} and you maybe died or not in Kategat...but 
        ciertanly feel like being in Valhala """)
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
        
    elif secret_character == 'Ivar - The Bonless':
        print (f"""
        After many days ... You reached {ports [1]} but Ivar is now in {ports [0]}.
        You try to walk to {ports [0]} you maybe died or not in Kategat...but no one really knows """)
        input (prompt = "\n\n You were not able to deliver the message")
        exit (0)
    else:
        print (""" You don't even leave the port... how can you think you can deliver the message?""")



# Win function
# Although some of the options have the same fixed text, each option includes the name of the character.
# Is the same situation than Fail function for not use a for loop.

def win ():
    if secret_character == 'Ragnar':
        input("press <Enter> to continue")
        print (f""" \n\n
        In our last trip, we finally have reached the port of {ports [0]} on time, drink a beer  and shouts \"Skol" 
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")
        
    
        
    elif secret_character == 'Lagertha':
        input("press <Enter> to continue")
        print (f""" \n\n
        In our last trip, we finally have have reached the port of {ports [0]} on time, go to Lagertha\'s Farm, drink a beer  
        and shouts \"Skol"  
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")

        
    elif secret_character == 'Floki':
        input("press <Enter> to continue")        
        print (f""" \n\n
        In our last trip, we finally have have reached the port of {ports [2]} on time, go to a cave, drink a beer and shouts \"Skol"  
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")

            
    elif secret_character == 'Rollo':
        input("press <Enter> to continue")        
        print (f""" \n\n
        In our last trip, we finally have reached the port of {ports [3]} on time, drink a wine in his place and shout 
        \"à votre santé"
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")

            
    elif secret_character == 'Bjorn Ironside':
        input("press <Enter> to continue")        
        print (f""" \n\n
        In our last trip, we finally have have reached the port of {ports [0]} on time, drink a beer  and shouts \"Skol"
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")

            
    elif secret_character == 'Ivar - The Bonless':
        input("press <Enter> to continue")        
        print (f""" \n\n
        In our last trip, we finally have have reached the port of {ports [0]} on time, drink a beer  and shouts \"Skol"
        """)
        print (f'\033[1m', end = " ") 
        print (F""" Now {secret_character} has the message """)
        print (f'\033[0m', end =" ")
    
    
    # The code print this last sentence for tell the user that has to run again the code for play again.
    # This print is for the cases in which the user wins the game.
    # I the cases in which the user loses the game, it supouse that is dead... and can't aboard a boat being dead.
    print ("""\n\n  Now we will get drunk for a couple of days... 
    If you want to continue being part of this crew, come in a few days.""")

    
start ()
# Out:
#     --------------------------------------------------------------------------------
#     Meet the Vikings
#     --------------------------------------------------------------------------------
#     As a true Viking, I suppose you are excited to be sailing again.
#     We only have one day left to start our new adventure and a great brave Viking is always welcome to join us.
# We only have names for recognized leaders. The rest of us are just Vikings.
#     So... tell me Viking, Do you have a message for one of our SIX leaders?
#
#
#  I understand that you are cautious and say a codename or even don't say anything at all...
#         in any case we were waiting for you.
#
#
#         The coat of arms that you have is that of to the well-known   --  Rollo. --
#  BUT... our captain likes riddles. Therefore, he will ask you some questions that you must answer as if you were--  Rollo. --
# ...
